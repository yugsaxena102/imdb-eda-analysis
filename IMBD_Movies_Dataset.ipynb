# %% [markdown]
# <a href="https://colab.research.google.com/github/yugsaxena102/imdb-eda-analysis/blob/main/IMBD_Movies_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies.csv")

# %%
pd.read_csv("/content/movies.csv")
# Out:
#                id                                         name  year  rating  \
# 0       tt0068646                                The Godfather  1972     9.2
# 1       tt5113044                     Minions: The Rise of Gru  2022     7.3
# 2       tt7657566                            Death on the Nile  2022     6.3
# 3       tt8115900                                 The Bad Guys  2022     6.9
# 4      tt10809742                                    Collision  2022     3.8
# ...           ...                                          ...   ...     ...
# 19803   tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804   tt0119621                      Mark Twain's America in  1998     6.5
# 19805   tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806   tt0267563                                       Hybrid  2000     7.4
# 19807   tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
# ...

# %% [markdown]
# # Q1. How do we load the dataset and see the first 5 rows?

# %%
df.head()
# Out:
#            id                      name  year  rating certificate duration  \
# 0   tt0068646             The Godfather  1972     9.2           R  175 min
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG   87 min
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13  127 min
# 3   tt8115900              The Bad Guys  2022     6.9          PG  100 min
# 4  tt10809742                 Collision  2022     3.8       TV-MA   99 min
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.tail()
# Out:
#               id                                         name  year  rating  \
# 19803  tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804  tt0119621                      Mark Twain's America in  1998     6.5
# 19805  tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                       Hybrid  2000     7.4
# 19807  tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate duration                       genre votes gross_income  \
# 19803   Not Rated  112 min            Biography, Drama    41       44,435
# 19804           G   52 min      Documentary, Biography    48    2,281,741
# 19805   Not Rated   75 min      Documentary, Biography   125        9,188
# 19806   Not Rated   92 min      Documentary, Biography   146      159,403
# 19807          PG   98 min  Documentary, Comedy, Drama  2167      492,876
#
# ...

# %%
df.sample(2)
# Out:
#               id         name  year  rating certificate duration  \
# 1343   tt0097967  Next of Kin  1989     5.8           R  108 min
# 10206  tt0152438  The Silence  1998     6.9   Not Rated   76 min
#
#                          genre  votes gross_income directors_id  \
# 1343   Action, Crime, Thriller  11689   15,942,628    nm0410139
# 10206             Drama, Music   1706       32,898    nm0538532
#
#           directors_name                                 stars_id  \
# 1343          John Irvin  nm0000664,nm0000553,nm0000284,nm0000166
# 10206  Mohsen Makhmalbaf  nm0635704,nm0008163,nm0955933,nm0794351
#
#                                               stars_name  \
# 1343   Patrick Swayze,Liam Neeson,Adam Baldwin,Helen ...
# 10206  Tahmineh Normatova,Nadereh Abdelahyeva,Goibibi...
#
#                                              description
# 1343   Truman, a Chicago cop, sets out to find the ki...
# 10206  Everyday, 10-year old Khorsid takes the bus to...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#                year        rating
# count  19808.000000  19808.000000
# mean    1995.546597      6.041973
# std       22.801725      1.206831
# min     1894.000000      1.100000
# 25%     1983.000000      5.300000
# 50%     2003.000000      6.200000
# 75%     2014.000000      6.900000
# max     2022.000000      9.700000

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19803    False
# 19804    False
# 19805    False
# 19806    False
# 19807    False
# Length: 19808, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#           id   name   year  rating  certificate  duration  genre  votes  \
# 0      False  False  False   False        False     False  False  False
# 1      False  False  False   False        False     False  False  False
# 2      False  False  False   False        False     False  False  False
# 3      False  False  False   False        False     False  False  False
# 4      False  False  False   False        False     False  False  False
# ...      ...    ...    ...     ...          ...       ...    ...    ...
# 19803  False  False  False   False        False     False  False  False
# 19804  False  False  False   False        False     False  False  False
# 19805  False  False  False   False        False     False  False  False
# 19806  False  False  False   False        False     False  False  False
# 19807  False  False  False   False        False     False  False  False
#
#        gross_income  directors_id  directors_name  stars_id  stars_name  \
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %%
df.count()
# Out:
# id                19808
# name              19808
# year              19808
# rating            19808
# certificate       19808
# duration          19808
# genre             19808
# votes             19808
# gross_income      19808
# directors_id      19808
# directors_name    19808
# stars_id          19808
# stars_name        19808
# description       19808
# dtype: int64

# %% [markdown]
# # **Q2. What are the datatype of each column?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %% [markdown]
# # Q3 How do we clean the duration column? (e.g., '175 min' - 175 )

# %%
df["duration"]
# Out:
# 0        175 min
# 1         87 min
# 2        127 min
# 3        100 min
# 4         99 min
#           ...
# 19803    112 min
# 19804     52 min
# 19805     75 min
# 19806     92 min
# 19807     98 min
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"].str.replace("min","")
# Out:
# 0        175
# 1         87
# 2        127
# 3        100
# 4         99
#          ...
# 19803    112
# 19804     52
# 19805     75
# 19806     92
# 19807     98
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"]
# Out:
# 0        175 min
# 1         87 min
# 2        127 min
# 3        100 min
# 4         99 min
#           ...
# 19803    112 min
# 19804     52 min
# 19805     75 min
# 19806     92 min
# 19807     98 min
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"] = df["duration"].str.replace("min","")

# %%
df["duration"]
# Out:
# 0        175
# 1         87
# 2        127
# 3        100
# 4         99
#          ...
# 19803    112
# 19804     52
# 19805     75
# 19806     92
# 19807     98
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"] = df["duration"].str.replace(",","")

# %%
df["duration"] = df["duration"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %%
df["duration"].mean()
# Out:
# np.float64(101.77796849757674)

# %% [markdown]
# # **Q4. How do we clean the `gross` column and `votes` column?**

# %%
df["votes"]
# Out:
# 0        1798749
# 1          1,220
# 2        121,063
# 3         23,090
# 4            656
#           ...
# 19803         41
# 19804         48
# 19805        125
# 19806        146
# 19807       2167
# Name: votes, Length: 19808, dtype: object

# %%
df["votes"] = df["votes"].str.replace(",","")

# %%
df["votes"]
# Out:
# 0        1798749
# 1           1220
# 2         121063
# 3          23090
# 4            656
#           ...
# 19803         41
# 19804         48
# 19805        125
# 19806        146
# 19807       2167
# Name: votes, Length: 19808, dtype: object

# %%
df["votes"] = df["votes"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.1+ MB

# %%
df["gross_income"]
# Out:
# 0        134,966,411
# 1        134,966,411
# 2        134,966,411
# 3        134,966,411
# 4        134,966,411
#             ...
# 19803         44,435
# 19804      2,281,741
# 19805          9,188
# 19806        159,403
# 19807        492,876
# Name: gross_income, Length: 19808, dtype: object

# %%
df["gross_income"] = df["gross_income"].str.replace(",","")

# %%
df["gross_income"]
# Out:
# 0        134966411
# 1        134966411
# 2        134966411
# 3        134966411
# 4        134966411
#            ...
# 19803        44435
# 19804      2281741
# 19805         9188
# 19806       159403
# 19807       492876
# Name: gross_income, Length: 19808, dtype: object

# %%
df["gross_income"] = df["gross_income"].str.replace("M","")

# %%
df["gross_income"] = df["gross_income"].str.replace("$","")

# %%
df["gross_income"] = df["gross_income"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  float64
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.1+ MB

# %% [markdown]
# # **Q5. How many missing values are in each column?**

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# # **Q6. How do we handle missing ratings?**

# %%
print(df["rating"].isnull().sum())      #Not any missing data
# Out:
# 0

# %% [markdown]
# # **Q7. Find the "Hidden Gems" (High Rating , Low Votes)**

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df[df["rating"] > 6.9 ]
# Out:
#               id                                  name  year  rating  \
# 0      tt0068646                         The Godfather  1972     9.2
# 1      tt5113044              Minions: The Rise of Gru  2022     7.3
# 5      tt0071562                 The Godfather Part II  1974     9.0
# 9      tt0071771                      The Longest Yard  1974     7.1
# 10     tt0993846               The Wolf of Wall Street  2013     8.2
# ...          ...                                   ...   ...     ...
# 19800  tt0044917                Amazing Monsieur Fabre  1951     7.0
# 19801  tt1334479                Yoo-Hoo, Mrs. Goldberg  2009     7.4
# 19802  tt1518255                             Raw Faith  2010     8.3
# 19806  tt0267563                                Hybrid  2000     7.4
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                          genre    votes  \
# 0               R       175                   Crime, Drama  1798749
# ...

# %%
df[df ["votes"] > 1058]
# Out:
#               id                                    name  year  rating  \
# 0      tt0068646                           The Godfather  1972     9.2
# 1      tt5113044                Minions: The Rise of Gru  2022     7.3
# 2      tt7657566                       Death on the Nile  2022     6.3
# 3      tt8115900                            The Bad Guys  2022     6.9
# 5      tt0071562                   The Godfather Part II  1974     9.0
# ...          ...                                     ...   ...     ...
# 19737  tt1972646      Eames: The Architect & The Painter  2011     7.1
# 19740  tt2174896                             To Be Takei  2014     6.9
# 19746  tt1839590  Ray Harryhausen: Special Effects Titan  2011     7.5
# 19789  tt0492499                     An Unreasonable Man  2006     7.9
# 19807  tt0116481    Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                         genre    votes  \
# ...

# %%
df[(df["rating"] > 6.9) & (df["votes"] > 1058)]
# Out:
#               id                                    name  year  rating  \
# 0      tt0068646                           The Godfather  1972     9.2
# 1      tt5113044                Minions: The Rise of Gru  2022     7.3
# 5      tt0071562                   The Godfather Part II  1974     9.0
# 9      tt0071771                        The Longest Yard  1974     7.1
# 10     tt0993846                 The Wolf of Wall Street  2013     8.2
# ...          ...                                     ...   ...     ...
# 19727  tt2040281                  Beauty Is Embarrassing  2012     7.5
# 19737  tt1972646      Eames: The Architect & The Painter  2011     7.1
# 19746  tt1839590  Ray Harryhausen: Special Effects Titan  2011     7.5
# 19789  tt0492499                     An Unreasonable Man  2006     7.9
# 19807  tt0116481    Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                           genre    votes  \
# ...

# %% [markdown]
# # **Q8. Find the "Overhyped" movies (Low rating , High votes)**

# %%
df.describe()
# Out:
#                year        rating      duration         votes  gross_income
# count  19808.000000  19808.000000  19808.000000  1.980800e+04  1.980800e+04
# mean    1995.546597      6.041973    101.777968  3.694303e+04  1.682198e+07
# std       22.801725      1.206831     43.178721  1.129755e+05  4.642034e+07
# min     1894.000000      1.100000      1.000000  5.000000e+00  0.000000e+00
# 25%     1983.000000      5.300000     90.000000  1.058000e+03  1.196010e+05
# 50%     2003.000000      6.200000     98.000000  4.233000e+03  1.158192e+06
# 75%     2014.000000      6.900000    111.000000  2.045350e+04  1.243278e+07
# max     2022.000000      9.700000   5220.000000  2.574832e+06  9.366622e+08

# %%
df[(df["rating"] > 5.30) & (df ["votes"] > 2058.5)]
# Out:
#               id                                  name  year  rating  \
# 0      tt0068646                         The Godfather  1972     9.2
# 2      tt7657566                     Death on the Nile  2022     6.3
# 3      tt8115900                          The Bad Guys  2022     6.9
# 5      tt0071562                 The Godfather Part II  1974     9.0
# 6      tt4998632                             Ambulance  2022     6.1
# ...          ...                                   ...   ...     ...
# 19703  tt2355540                   Cutie and the Boxer  2013     7.2
# 19704  tt0118635                                Aprile  1998     6.9
# 19705  tt1568150          Joan Rivers: A Piece of Work  2010     7.3
# 19718  tt2304915                      The Green Prince  2014     7.2
# 19807  tt0116481  Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate  duration                           genre    votes  \
# ...

# %% [markdown]
# # **Q8. Find the "Overhyped" movies (Low rating , High gross)**

# %%
df[(df["rating"] < 5.30) & (df ["gross_income"] > 12432780)]
# Out:
#                id                         name  year  rating certificate  \
# 4      tt10809742                    Collision  2022     3.8       TV-MA
# 18     tt11656220  Midnight in the Switchgrass  2021     4.4           R
# 37      tt6749318                  Speed Kills  2018     4.2           R
# 40      tt5433138            F9: The Fast Saga  2021     5.2       PG-13
# 47      tt1551614                     Blowback  2022     4.4           R
# ...           ...                          ...   ...     ...         ...
# 18575   tt1389139        When the Bough Breaks  2016     5.1       PG-13
# 18615   tt8170298                   John Henry  2020     3.6           R
# 18616   tt6469960          An Imperfect Murder  2017     3.2           R
# 18717   tt1859573             Pretty Obsession  2012     4.2   Not Rated
# 19592   tt0074562            Gable and Lombard  1976     5.1           R
#
#        duration                      genre   votes  gross_income directors_id  \
# ...

# %% [markdown]
# # **Q9. What are the unique certificates in the dataset?**

# %%
df["certificate"].unique()
# Out:
# array(['R', 'PG', 'PG-13', 'TV-MA', 'Not Rated', 'Approved', 'TV-14',
#        'NC-17', 'Unrated', 'G', 'Passed', 'GP', 'X', 'M/PG', 'M', 'TV-PG',
#        'TV-G', '12', 'TV-13', 'TV-Y7-FV', 'MA-17', 'AO', '18', 'R-15',
#        'R-12', 'R-18', 'PG-12', '6+', 'TV-Y7', 'TV-Y', 'MA-13'],
#       dtype=object)

# %%
df["certificate"].nunique()
# Out:
# 31

# %% [markdown]
# # **Q10. How many movies were released each year?**

# %%
df.groupby("year")["id"].count()
# Out:
# year
# 1894      1
# 1898      1
# 1902      2
# 1903      1
# 1913      3
#        ...
# 2018    736
# 2019    657
# 2020    467
# 2021    470
# 2022    174
# Name: id, Length: 114, dtype: int64

# %%
df.groupby("year")["id"].count().sort_values(ascending= False)
# Out:
# year
# 2018    736
# 2017    714
# 2016    665
# 2019    657
# 2014    640
#        ...
# 1898      1
# 1919      1
# 1903      1
# 1917      1
# 1894      1
# Name: id, Length: 114, dtype: int64

# %%
df["year"].value_counts()
# Out:
# year
# 2018    736
# 2017    714
# 2016    665
# 2019    657
# 2014    640
#        ...
# 1919      1
# 1898      1
# 1894      1
# 1917      1
# 1903      1
# Name: count, Length: 114, dtype: int64

# %%
df["year"].value_counts().sort_index(ascending= False)
# Out:
# year
# 2022    174
# 2021    470
# 2020    467
# 2019    657
# 2018    736
#        ...
# 1913      3
# 1903      1
# 1902      2
# 1898      1
# 1894      1
# Name: count, Length: 114, dtype: int64

# %% [markdown]
# # **Q11. Which are the top 5 most common genres?**

# %%
top_5_genres = df["genre"].value_counts().head(5)

# %%
print(top_5_genres)
# Out:
# genre
# Action, Crime, Drama      734
# Crime, Drama, Thriller    522
# Crime, Drama              430
# Drama, Thriller           422
# Horror                    411
# Name: count, dtype: int64

# %% [markdown]
# # **Q12. Which directors have directed the most movies?**

# %%
df["directors_name"].str.split(",").value_counts().head(10)
# Out:
# directors_name
# [Alfred Hitchcock]    38
# [Clint Eastwood]      36
# [Henry Hathaway]      29
# [Steven Spielberg]    29
# [Raoul Walsh]         27
# [John Ford]           26
# [Jesús Franco]        26
# [John Huston]         25
# [Ridley Scott]        25
# [Gordon Douglas]      24
# Name: count, dtype: int64

# %% [markdown]
# # **Q13. Do longer movies get better ratings?**

# %%
df["directors_name"]
# Out:
# 0                            Francis Ford Coppola
# 1        Kyle Balda,Brad Ableson,Jonathan del Val
# 2                                 Kenneth Branagh
# 3                                  Pierre Perifel
# 4                                Fabien Martorell
#                            ...
# 19803                            Prabhakar Shukla
# 19804                                 Stephen Low
# 19805                           Jennifer Baichwal
# 19806           Monteith McCollum,Milford Beeghly
# 19807                                S.R. Bindler
# Name: directors_name, Length: 19808, dtype: object

# %%
df["directors_name"].str.split(",")
# Out:
# 0                              [Francis Ford Coppola]
# 1        [Kyle Balda, Brad Ableson, Jonathan del Val]
# 2                                   [Kenneth Branagh]
# 3                                    [Pierre Perifel]
# 4                                  [Fabien Martorell]
#                              ...
# 19803                              [Prabhakar Shukla]
# 19804                                   [Stephen Low]
# 19805                             [Jennifer Baichwal]
# 19806            [Monteith McCollum, Milford Beeghly]
# 19807                                  [S.R. Bindler]
# Name: directors_name, Length: 19808, dtype: object

# %%
df["directors_name"].str.split(",").explode()
# Out:
# 0        Francis Ford Coppola
# 1                  Kyle Balda
# 1                Brad Ableson
# 1            Jonathan del Val
# 2             Kenneth Branagh
#                  ...
# 19804             Stephen Low
# 19805       Jennifer Baichwal
# 19806       Monteith McCollum
# 19806         Milford Beeghly
# 19807            S.R. Bindler
# Name: directors_name, Length: 22014, dtype: object

# %%
df["directors_name"].str.split(",").explode()
# Out:
# 0        Francis Ford Coppola
# 1                  Kyle Balda
# 1                Brad Ableson
# 1            Jonathan del Val
# 2             Kenneth Branagh
#                  ...
# 19804             Stephen Low
# 19805       Jennifer Baichwal
# 19806       Monteith McCollum
# 19806         Milford Beeghly
# 19807            S.R. Bindler
# Name: directors_name, Length: 22014, dtype: object

# %%
number_of_movies = df["directors_name"].str.split(",").explode()

# %%
number_of_movies.value_counts().sort_values(ascending=False).head(10)
# Out:
# directors_name
# Clint Eastwood      38
# Alfred Hitchcock    38
# Henry Hathaway      31
# John Ford           31
# Raoul Walsh         31
# Steven Spielberg    30
# John Huston         29
# Jesús Franco        28
# Martin Scorsese     26
# Gordon Douglas      26
# Name: count, dtype: int64

# %% [markdown]
# # **Spearman corelation**

# %% [markdown]
# # **Q13. Do longer movies get better ratings?**

# %%
df[["duration","rating"]]
# Out:
#        duration  rating
# 0           175     9.2
# 1            87     7.3
# 2           127     6.3
# 3           100     6.9
# 4            99     3.8
# ...         ...     ...
# 19803       112     6.2
# 19804        52     6.5
# 19805        75     6.9
# 19806        92     7.4
# 19807        98     7.6
#
# [19808 rows x 2 columns]

# %%
df[["duration","rating"]].corr()
# Out:
#           duration    rating
# duration  1.000000  0.130112
# rating    0.130112  1.000000

# %% [markdown]
# # **Q14. Which genre has the highest average rating?**

# %%
df["genre"]
# Out:
# 0                        Crime, Drama
# 1        Animation, Adventure, Comedy
# 2               Crime, Drama, Mystery
# 3        Animation, Adventure, Comedy
# 4              Crime, Drama, Thriller
#                      ...
# 19803                Biography, Drama
# 19804          Documentary, Biography
# 19805          Documentary, Biography
# 19806          Documentary, Biography
# 19807      Documentary, Comedy, Drama
# Name: genre, Length: 19808, dtype: object

# %%
df_exploded = df["genre"].str.split(",").explode()

# %%
df_exploded = df.assign(genre = df["genre"].str.split(",")).explode("genre")

# %%
df_exploded.groupby("genre")["rating"].mean().sort_values(ascending = False).head()
# Out:
# genre
# Documentary    7.187100
#  Short         7.117143
#  Reality-TV    7.100000
#  Biography     7.090317
# Short          6.997674
# Name: rating, dtype: float64

# %% [markdown]
# # **Q15. Which genre makes the most money (Avg Gross)?**

# %%
avg_gross = df.groupby("genre")["gross_income"].mean().sort_values(ascending=False)

# %%
top_genre = avg_gross.idxmax()
top_value = avg_gross.max()

# %%
print(f"Genre with highest average gross: {top_genre}")
# Out:
# Genre with highest average gross: Music, Romance, Sci-Fi

# %%
print(f"Average Gross: {top_value:,.2f}")
# Out:
# Average Gross: 209,726,015.00

# %% [markdown]
# # **Q16. Who is the highest-grossing director of all time (in this dataset)?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  float64
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.1+ MB

# %%
director_gross = df.groupby("directors_name")["gross_income"].sum().sort_values(ascending=False)

# %%
top_director = director_gross.idxmax()
top_gross = director_gross.max()

# %%
print(f"Highest-grossing director: {top_director}")
# Out:
# Highest-grossing director: Steven Spielberg

# %%
print(f"Total Gross: ${top_gross:,.2f}")
# Out:
# Total Gross: $4,247,700,467.00

# %% [markdown]
# # **Q17. How does Certificate affect Gross Income?**

# %%
df[["certificate","gross_income"]]
# Out:
#       certificate  gross_income
# 0               R   134966411.0
# 1              PG   134966411.0
# 2           PG-13   134966411.0
# 3              PG   134966411.0
# 4           TV-MA   134966411.0
# ...           ...           ...
# 19803   Not Rated       44435.0
# 19804           G     2281741.0
# 19805   Not Rated        9188.0
# 19806   Not Rated      159403.0
# 19807          PG      492876.0
#
# [19808 rows x 2 columns]

# %%
df.groupby("certificate")["gross_income"].mean().sort_values(ascending=False).head()
# Out:
# certificate
# GP       6.221153e+07
# PG-13    4.571531e+07
# MA-17    3.806747e+07
# R-18     3.474929e+07
# PG       2.997915e+07
# Name: gross_income, dtype: float64

# %% [markdown]
# # **Q18. What is the average duration of movies by Certificate?**

# %%
df.groupby("certificate")["duration"].mean().sort_values(ascending=False)
# Out:
# certificate
# R-15         127.333333
# R-18         126.571429
# R-12         123.339623
# PG-12        117.540984
# 6+           114.000000
# M/PG         110.666667
# PG-13        106.786859
# M            105.793103
# Not Rated    104.813337
# GP           104.362963
# Unrated      104.237410
# NC-17        103.320000
# R            102.299871
# TV-MA        101.150808
# MA-17        101.000000
# PG           100.713953
# TV-14         95.834302
# X             95.361111
# G             92.117647
# Approved      91.045694
# 18            91.000000
# Passed        89.201220
# TV-PG         89.167883
# TV-13         88.000000
# TV-Y7         84.476190
# TV-G          81.613636
# AO            81.000000
# MA-13         80.500000
# TV-Y          74.000000
# 12            71.000000
# TV-Y7-FV      63.166667
# Name: duration, dtype: float64

# %% [markdown]
# # **Q19. Are ratings improving over the years?**

# %%
df.groupby("year")["rating"].mean().reset_index()
# Out:
#      year    rating
# 0    1894  5.300000
# 1    1898  7.500000
# 2    1902  7.400000
# 3    1903  6.400000
# 4    1913  6.400000
# ..    ...       ...
# 109  2018  5.935598
# 110  2019  5.914460
# 111  2020  5.577516
# 112  2021  5.741064
# 113  2022  5.481609
#
# [114 rows x 2 columns]

# %% [markdown]
# # **Q20. Which actor appears in the most movies?**

# %%
actor_counts = df["stars_name"].value_counts()

# %%
actor_counts.idxmax()
# Out:
# 'William Shatner,Leonard Nimoy,DeForest Kelley,James Doohan'

# %%
top_actor = actor_counts.idxmax()

# %%
top_count = actor_counts.max()

# %%
print(f"Actor appearing in the most movies: {top_actor}")
# Out:
# Actor appearing in the most movies: William Shatner,Leonard Nimoy,DeForest Kelley,James Doohan

# %% [markdown]
# # **Q21. What is the correlation between Votes and Gross Income?**

# %%
df["votes"].corr(df["gross_income"])
# Out:
# np.float64(0.6326831775869199)

# %%
correlation = df["votes"].corr(df["gross_income"])

# %%
print(f"Correlation between Votes and Gross Income: {correlation:.2f}")
# Out:
# Correlation between Votes and Gross Income: 0.63

# %% [markdown]
# # **Q22. Which Director + Actor duo is the most frequent?**

# %%
duo_counts = (df.groupby(["directors_name" , "stars_name"]).size().reset_index(name="movie_count").sort_values(by="movie_count",ascending=False))

# %%
top_duo = duo_counts.iloc[0]

# %%
print("Most Frequent Director + Actor Duo:")
print(f"Director: {top_duo['directors_name']}")
print(f"Actor: {top_duo['stars_name']}")
print(f"Movies Together: {top_duo['movie_count']}")
# Out:
# Most Frequent Director + Actor Duo:
# Director: Lana Wachowski,Lilly Wachowski
# Actor: Keanu Reeves,Laurence Fishburne,Carrie-Anne Moss,Hugo Weaving
# Movies Together: 3

# %%
top10 = duo_counts.head(10).copy()

# %%
top10["duo"] = top10["directors_name"] + " + " + top10["stars_name"]

# %% [markdown]
# # **Q23. Which year had the highest total industry revenue?**

# %%
Yearly_revenue = (df.groupby("year")["gross_income"].sum().sort_values(ascending=False))

# %%
top_year = Yearly_revenue.idxmax()
top_revenue = Yearly_revenue.max()

# %%
print(f"Year with highest total revenue: {top_year}")
print(f"Total Revenue: {top_revenue:,.2f}")
# Out:
# Year with highest total revenue: 2021
# Total Revenue: 20,454,259,520.10

# %% [markdown]
# # **Q24. What is the best genre for a debut director? (Highest avg rating for 1st time directors)**

# %%
df_exploded.groupby('genre')['rating'].mean().sort_values(ascending=False).head()
# Out:
# genre
# Documentary    7.187100
#  Short         7.117143
#  Reality-TV    7.100000
#  Biography     7.090317
# Short          6.997674
# Name: rating, dtype: float64

# %% [markdown]
# euu

# %%
df["director_first_year"] = df.groupby("directors_name")["year"].transform("min")

debut_df = df[df["year"] == df["director_first_year"]]

genre_rating = (debut_df.groupby("genre")["rating"].mean().sort_values(ascending=False))

# %%
best_genre = genre_rating.idxmax()
best_rating = genre_rating.max()

# %%
print(f"Best Genre for Debut Directors: {best_genre}")
print(f"Average Rating: {best_rating:.2f}")
# Out:
# Best Genre for Debut Directors: Short, Comedy, Sci-Fi
# Average Rating: 9.00

# %% [markdown]
# # **Q25. Do movies with more actors (ensemble cast) earn more?**

# %%
df_exploded = df.assign(stars_name=df["stars_name"].str.split(",")).explode("stars_name")

# %%
actor_count = df_exploded.groupby("name")["stars_name"].count().reset_index()
actor_count.columns = ["name", "actor_count"]

# %%
merged = df_exploded[["name", "gross_income"]].drop_duplicates().merge(actor_count, on="name")

# %%
correlation = merged["actor_count"].corr(merged["gross_income"])
print(f"Correlation between number of actors and gross: {correlation:.2f}")
# Out:
# Correlation between number of actors and gross: 0.02

# %% [markdown]
# # **Q26. Which Director has the highest "Hit Rate"? (Percentage of movies rated > 7.5)**

# %%
df["is_hit"] = df["rating"] > 7.5

# %%
director_stats = df.groupby("directors_name").agg(
    total_movies=("name", "count"),
    hit_movies=("is_hit", "sum")
)

# %%
director_stats["hit_rate"] = (
    director_stats["hit_movies"] / director_stats["total_movies"]
)

# %%
filtered = director_stats[director_stats["total_movies"] >= 3]

# %%
top_director = filtered.sort_values("hit_rate", ascending=False).head(1)

# %%
print("Director with Highest Hit Rate:")
print(top_director)
# Out:
# Director with Highest Hit Rate:
#                                   total_movies  hit_movies  hit_rate
# directors_name
# Yukihiro Miyamoto,Akiyuki Shinbo             3           3       1.0

# %% [markdown]
# # **Q27. Analyse the "Sequel Effect" — Do movies with numbers in titles earn more?**

# %%
df["is_sequel"] = df["name"].str.contains(r"\b\d+\b|II|III|IV|V", regex=True)      # Detect sequel-like titles (contain numbers)

# %%
sequel_stats = df.groupby("is_sequel")["gross_income"].mean()

# %%
print("Average Gross Income:")
print(sequel_stats)
# Out:
# Average Gross Income:
# is_sequel
# False    1.608569e+07
# True     2.545265e+07
# Name: gross_income, dtype: float64

# %% [markdown]
# # **Q28. The Ultimate Business Decision: What movie should we fund?**

# %%
#Successful_movies

threshold = df["gross_income"].quantile(0.75)
top_movies = df[df["gross_income"] >= threshold]

# %%
#Best_Genre
top_movies["genre"].value_counts().head(10)
# Out:
# genre
# Animation, Adventure, Comedy    203
# Action, Crime, Drama            176
# Action, Adventure, Sci-Fi       146
# Action, Adventure, Comedy       143
# Action, Comedy, Crime           115
# Action, Crime, Thriller         111
# Crime, Drama, Thriller          108
# Crime, Drama, Mystery           106
# Horror, Mystery, Thriller       101
# Action, Adventure, Drama         96
# Name: count, dtype: int64

# %%
#Best_Certificate
top_movies["certificate"].value_counts()
# Out:
# certificate
# R            1900
# PG-13        1270
# PG            870
# Not Rated     276
# G             154
# TV-MA         127
# Approved       90
# GP             58
# Passed         50
# TV-14          48
# Unrated        32
# R-12           17
# PG-12          17
# TV-PG          13
# TV-G            6
# R-15            6
# M               5
# TV-Y7           4
# X               2
# NC-17           2
# M/PG            2
# R-18            2
# MA-17           1
# Name: count, dtype: int64

# %%
#Best_Directors
top_movies["directors_name"].value_counts().head(10)
# Out:
# directors_name
# Clint Eastwood       31
# Steven Spielberg     27
# Ridley Scott         21
# Ron Howard           18
# Tim Burton           18
# Wes Craven           16
# Michael Bay          15
# Steven Soderbergh    15
# Joel Schumacher      14
# Antoine Fuqua        14
# Name: count, dtype: int64

# %%
#Best_Stars
top_movies["stars_name"].value_counts().head(10)
# Out:
# stars_name
# William Shatner,Leonard Nimoy,DeForest Kelley,James Doohan        6
# Sylvester Stallone,Talia Shire,Burt Young,Carl Weathers           3
# Patrick Stewart,Jonathan Frakes,Brent Spiner,LeVar Burton         3
# Keanu Reeves,Laurence Fishburne,Carrie-Anne Moss,Hugo Weaving     3
# Mark Hamill,Harrison Ford,Carrie Fisher,Billy Dee Williams        2
# Leslie Nielsen,Priscilla Presley,George Kennedy,O.J. Simpson      2
# Tyler Perry,Cassi Davis,Patrice Lovely,Yousef Erakat              2
# Bill Murray,Dan Aykroyd,Sigourney Weaver,Harold Ramis             2
# Megumi Ogata,Megumi Hayashibara,Yûko Miyamura,Kotono Mitsuishi    2
# Shia LaBeouf,Megan Fox,Josh Duhamel,Tyrese Gibson                 2
# Name: count, dtype: int64

# %% [markdown]
# # **VISUALISATION**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Q1. Plot the number of movies released per year**

# %%
df.groupby("year")["id"].count()
# Out:
# year
# 1894      1
# 1898      1
# 1902      2
# 1903      1
# 1913      3
#        ...
# 2018    736
# 2019    657
# 2020    467
# 2021    470
# 2022    174
# Name: id, Length: 114, dtype: int64

# %%
mpy = df.groupby("year")["id"].count()

# %%
plt.plot(mpy.index , mpy.values)

# %% [markdown]
# # **Q2. Plot the average movies rating over the years**

# %%
df.groupby("certificate")["gross_income"].mean().sort_values(ascending= False).head()
# Out:
# certificate
# GP       6.221153e+07
# PG-13    4.571531e+07
# MA-17    3.806747e+07
# R-18     3.474929e+07
# PG       2.997915e+07
# Name: gross_income, dtype: float64

# %%
df.groupby("year")["rating"].mean()
# Out:
# year
# 1894    5.300000
# 1898    7.500000
# 1902    7.400000
# 1903    6.400000
# 1913    6.400000
#           ...
# 2018    5.935598
# 2019    5.914460
# 2020    5.577516
# 2021    5.741064
# 2022    5.481609
# Name: rating, Length: 114, dtype: float64

# %%
roy = df.groupby("year")["rating"].mean()

# %%
plt.plot(roy.index , roy.values , color = "purple")
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(roy.index , roy.values , color = "purple")
plt.xlabel("year")
plt.ylabel("Average Rating")
plt.grid()
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.plot(roy.index , roy.values , color = "purple" , marker = "*" , linestyle = ":" , markersize = 5)
plt.xlabel("year")
plt.ylabel("Average Rating")
plt.grid(alpha = 0.15)
plt.show()

# %% [markdown]
# # **Q3. Plot the distribution of movie ratings**

# %%
plt.figure(figsize = (10 , 6))
plt.hist(df["rating"] , color = "magenta" , edgecolor = "black" , bins = 25)
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.title("Distribution of movie ratings")
plt.grid(alpha = 0.25)
plt.show()

# %% [markdown]
# # **Q4. Plot the distribution of movie ratings**
#
# 1.   List item
# 2.   List item

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize = (10,6))
sns.histplot(df["rating"] , color = "green" , bins = 20, kde = True)
plt.title("Distribution of Movie Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # **Q5. Which are the top 10 most frequent actors?**

# %%
df["stars_name"].str.split(",").explode().value_counts()
# Out:
# stars_name
# Nicolas Cage           76
# Samuel L. Jackson      72
# Bruce Willis           71
# John Wayne             71
# Robert De Niro         62
#                        ..
# Michelle Akers          1
# Jan Armstrong           1
# Faye Austin             1
# Ruth Gruber             1
# Louisa Herz Leopold     1
# Name: count, Length: 35107, dtype: int64

# %%
fa = df["stars_name"].str.split(",").explode().value_counts().head(10)

# %%
plt.figure(figsize = (10,6))
plt.barh(fa.index , fa.values , color = ["red" , "blue" , "orange" , "green"])
plt.xticks(rotation = 45)
plt.grid(False)
plt.show()

# %% [markdown]
# # **Q6. Plot the relationship between year and rating**

# %%
plt.figure(figsize = (10,6))
plt.scatter(df["year"] , df["rating"] , marker = "*")

plt.xlabel("Year")
plt.ylabel("Rating")
plt.title("Relationship Between Year and Rating")
plt.grid(False)
plt.show()

# %% [markdown]
# # **Q7. Plot the distribution of Gross Income and Votes**

# %%
plt.figure(figsize = (12,6))

sns.boxplot(data=df[["gross_income" , "votes"]])

plt.title("Distribution of Gross Income and Votes")
plt.xlabel("Features")
plt.ylabel("values")

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Gross Income Box Plot
sns.boxplot(y=df['gross_income'], ax=axes[0], color='skyblue')
axes[0].set_title('Gross Income Distribution')

# Votes Box Plot
sns.boxplot(y=df['votes'], ax=axes[1], color='orange')
axes[1].set_title('Votes Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q8. Plot the count of movies for the top actors**

# %%
top_actors = df["stars_name"].value_counts().head()

# %%
plt.figure(figsize = (10,6))

sns.countplot(y = "stars_name", data = df, order =top_actors.index, hue="stars_name", palette= "viridis" , legend=False)

plt.title("Top 10 Actors by Number of Movies")
plt.xlabel("Movie_count")
plt.ylabel("stars_name")
plt.show()

# %% [markdown]
# # **Q9. Plot the correlation between Rating, Votes, and Gross Income**

# %%
cols = ["rating" , "votes" , "gross_income"]
data = df[cols]

# %%
corr = data.corr()

# %%
plt.figure(figsize = (10,6))
sns.heatmap(
    corr,
    annot = True,
    cmap = "coolwarm",
    vmin = -1,
    vmax = 1,
    linewidths=0.5
)

plt.title("Correlation Between Rating , Votes , Gross Income")
plt.show()

# %% [markdown]
# # **Q10. Plot the correlation of all numeric columns**

# %%
numeric_df = df.select_dtypes(include = ["number"])

corr = numeric_df.corr()

plt.figure(figsize = (10,6))

sns.heatmap(
    corr,
    annot = True,
    cmap = "coolwarm",
    fmt = ".2f",
    linewidths= 0.5
    )

plt.title("Correlation Heatmap(All Numeric Columns)")
plt.show()
